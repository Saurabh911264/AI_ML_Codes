# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd /content/gdrive/MyDrive
# Out:
# /content/gdrive/MyDrive

# %%
import os
if not os.path.isdir("AIDetection"):
  os.makedirs("AIDetection")

# %%
# %cd /content/gdrive/MyDrive/AIDetection
# Out:
# /content/gdrive/MyDrive/AIDetection

# %%
# !git clone https://github.com/WongKinYiu/yolov7.git
# Out:
# fatal: destination path 'yolov7' already exists and is not an empty directory.

# %%
# !wget https://github.com/WongKinYiu/yolov7/releases
# Out:
# --2023-04-18 06:27:27--  https://github.com/WongKinYiu/yolov7/releases
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘releases’
#
# releases                [ <=>                ] 123.40K  --.-KB/s    in 0.1s
#
# 2023-04-18 06:27:27 (1.25 MB/s) - ‘releases’ saved [126362]

# %%
cd yolov7-custom
# Out:
# [Errno 2] No such file or directory: 'yolov7-custom'
# /content

# %%
# !python train.py --device --batch-size 16 --epochs 100 --img 640 640 --data data/custom_data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training
