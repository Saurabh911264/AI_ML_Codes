# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset = pd.read_csv(r'/content/drive/My Drive/Machine_Learning/Hotel_bookings.csv')
print(dataset, "\n")
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
dataset.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
print(dataset.isnull().sum())
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
dataset = dataset.dropna()
dataset.head()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 2392  Resort Hotel            0          6               2015
# 2697  Resort Hotel            0         24               2015
# 2867  Resort Hotel            0         24               2015
# 2877  Resort Hotel            0         24               2015
# 2878  Resort Hotel            0         24               2015
#
#      arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 2392            October                        42                         11
# 2697            October                        44                         26
# 2867           November                        45                          3
# 2877           November                        45                          3
# 2878           November                        45                          3
#
#       stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# ...

# %%
print(dataset['country'].head())
# Out:
# 2392    PRT
# 2697    AUT
# 2867    ESP
# 2877    PRT
# 2878    ITA
# Name: country, dtype: object

# %%
dataset['country'].fillna((dataset['country'].value_counts().index[0]), inplace=True)

# %%
print(dataset['country'].head())
# Out:
# 2392    PRT
# 2697    AUT
# 2867    ESP
# 2877    PRT
# 2878    ITA
# Name: country, dtype: object

# %%
dataset['agent'].fillna((dataset['agent'].value_counts().index[0]), inplace=True)

# %%
dataset['company'].fillna((dataset['company'].value_counts().index[0]), inplace=True)

# %%
print(dataset.head(20))
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 2392  Resort Hotel            0          6               2015
# 2697  Resort Hotel            0         24               2015
# 2867  Resort Hotel            0         24               2015
# 2877  Resort Hotel            0         24               2015
# 2878  Resort Hotel            0         24               2015
# 2879  Resort Hotel            0         24               2015
# 2880  Resort Hotel            0         24               2015
# 2881  Resort Hotel            0         24               2015
# 2882  Resort Hotel            0         24               2015
# 2883  Resort Hotel            0         24               2015
# 2884  Resort Hotel            0         24               2015
# 2892  Resort Hotel            0         33               2015
# 2898  Resort Hotel            0         34               2015
# 2900  Resort Hotel            0         34               2015
# ...

# %%
dataset = pd.read_csv(r'/content/drive/My Drive/Machine_Learning/Hotel_bookings.csv')
print(dataset, "\n")
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...
